# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel(r"C:\Users\jayasree\aspiring_minds_employability_outcomes_2015 (2).xlsx")

# %%
df
# Out:
#      Unnamed: 0      ID   Salary        DOJ                  DOL  \
# 0         train  203097   420000 2012-06-01              present
# 1         train  579905   500000 2013-09-01              present
# 2         train  810601   325000 2014-06-01              present
# 3         train  267447  1100000 2011-07-01              present
# 4         train  343523   200000 2014-03-01  2015-03-01 00:00:00
# ...         ...     ...      ...        ...                  ...
# 3993      train   47916   280000 2011-10-01  2012-10-01 00:00:00
# 3994      train  752781   100000 2013-07-01  2013-07-01 00:00:00
# 3995      train  355888   320000 2013-07-01              present
# 3996      train  947111   200000 2014-07-01  2015-01-01 00:00:00
# 3997      train  324966   400000 2013-02-01              present
#
#                       Designation           JobCity Gender        DOB  \
# 0         senior quality engineer         Bangalore      f 1990-02-19
# ...

# %%
df['Unnamed: 0'].value_counts()
# Out:
# train    3998
# Name: Unnamed: 0, dtype: int64

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df
# Out:
#           ID   Salary        DOJ                  DOL  \
# 0     203097   420000 2012-06-01              present
# 1     579905   500000 2013-09-01              present
# 2     810601   325000 2014-06-01              present
# 3     267447  1100000 2011-07-01              present
# 4     343523   200000 2014-03-01  2015-03-01 00:00:00
# ...      ...      ...        ...                  ...
# 3993   47916   280000 2011-10-01  2012-10-01 00:00:00
# 3994  752781   100000 2013-07-01  2013-07-01 00:00:00
# 3995  355888   320000 2013-07-01              present
# 3996  947111   200000 2014-07-01  2015-01-01 00:00:00
# 3997  324966   400000 2013-02-01              present
#
#                       Designation           JobCity Gender        DOB  \
# 0         senior quality engineer         Bangalore      f 1990-02-19
# 1               assistant manager            Indore      m 1989-10-04
# 2                systems engineer           Chennai      f 1992-08-03
# ...

# %%
df.shape
# Out:
# (3998, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   int64
#  2   DOJ                    3998 non-null   datetime64[ns]
#  3   DOL                    3998 non-null   object
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   datetime64[ns]
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
df["Domain"].unique()
# Out:
# array([ 0.63597876,  0.96060325,  0.45087658,  0.97439611,  0.12450207,
#        -1.        ,  0.35653649,  0.8295846 ,  0.69447933,  0.49359639,
#         0.76567358,  0.9682375 ,  0.22948175,  0.53838689,  0.30840058,
#         0.91139528,  0.56326782,  0.86468541,  0.64938971,  0.74475835,
#         0.88412251,  0.88162007,  0.20739217,  0.48674701,  0.67074315,
#         0.62264292,  0.41383826,  0.52592258,  0.73579571,  0.13044174,
#         0.23780284,  0.11213944,  0.37755142,  0.06696071,  0.08005528,
#         0.92564577,  0.84312373,  0.91686996,  0.78330354,  0.60005718,
#         0.79293628,  0.79358061,  0.16563309,  0.75537512,  0.99990456,
#         0.33878635,  0.91077016,  0.98205712,  0.84224832,  0.01854094,
#         0.05316031,  0.94211655,  0.12301673,  0.48834798,  0.37605959,
#         0.0587928 ,  0.10487136,  0.60064396,  0.70409041,  0.14478989,
#         0.81941653,  0.65576694,  0.02106623,  0.44461772,  0.83762073,
# ...

# %% [markdown]
# ### Bar plots
# * This is one of the widely used plot, that we would have saw multiple times not just in data analysis, but wherever there is a trend analysis in many fields. Though it may seem simple it is powerful in analyzing data like sales figure every week, revenue from a product, Number of visitors to a site on each day of a week etc.

# %%
sns.barplot(hue="Degree",x='Gender',y='Salary',data=df)

# %% [markdown]
# ### Observations
# * Using barplot we found male and female degree with thier Salary.
# * Female Salary is more comapre to male salary.
# * The most Salaries in M.Tech/M.E compare to other Degrees.

# %% [markdown]
# ### Data of joining

# %%
df['DOJ'].value_counts()
# Out:
# 2014-07-01    199
# 2014-06-01    180
# 2014-08-01    178
# 2014-09-01    142
# 2014-01-01    142
#              ...
# 2004-08-01      1
# 2015-11-01      1
# 2006-01-01      1
# 2007-09-01      1
# 2015-12-01      1
# Name: DOJ, Length: 81, dtype: int64

# %%
d= []
for i in df.DOJ:
    d.append(i.strftime('%Y %b'))
df['DOJ']=d

# %%
plt.figure(figsize=(18,6))
sns.countplot(x='DOJ',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observations
# * The strftime() method returns a string representing date and time using date, time or datetime object.
# * Countplot shows the group of candidtaes joined in differnt dates.
# * From the above countplot most number of candidates joined on 2014 july with 200 members.
# * The number of unique joined dates 81.

# %% [markdown]
# ### Data of leaving

# %%
df['DOL'].value_counts()
# Out:
# present                1875
# 2015-04-01 00:00:00     573
# 2015-03-01 00:00:00     124
# 2015-05-01 00:00:00     112
# 2015-01-01 00:00:00      99
#                        ...
# 2015-10-01 00:00:00       1
# 2008-03-01 00:00:00       1
# 2010-10-01 00:00:00       1
# 2005-03-01 00:00:00       1
# 2011-02-01 00:00:00       1
# Name: DOL, Length: 67, dtype: int64

# %%
l= []
for i in df.DOL:
    if 'present' == i:
        l.append('present')
    else:
        l.append(i.strftime('%Y %b'))
df['DOL']=l

# %%
plt.figure(figsize=(18,6))
df['DOL'].value_counts().plot(kind='bar')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
# * From the above plot Most of the members nearly 1800 are still working according to the dataset.
# * In this dataset total number of joined unique dates are 67.
# * Most of the members are leaving company in 2015 April.

# %% [markdown]
# ## Designation

# %%
df['Designation'].value_counts()
# Out:
# software engineer                539
# software developer               265
# system engineer                  205
# programmer analyst               139
# systems engineer                 118
#                                 ...
# controls engineer                  1
# software designer                  1
# software test engineerte           1
# sap abap associate consultant      1
# quality assurance auditor          1
# Name: Designation, Length: 419, dtype: int64

# %%
df.Designation.value_counts().nlargest(20).plot.bar()
plt.show()

# %% [markdown]
# ### Observations
# * There are different types Designations in the dataset,here we found the Designation with count.
# * The heighest number of employees 500+ in Software engineer.
# * The number of unique Designatipons are 419.

# %% [markdown]
# ## Jobcity

# %%
df["JobCity"].value_counts()
# Out:
# Bangalore         627
# -1                461
# Noida             368
# Hyderabad         335
# Pune              290
#                  ...
# Bulandshahar        1
# angul               1
# RAS AL KHAIMAH      1
# Dharmapuri          1
# Dausa               1
# Name: JobCity, Length: 339, dtype: int64

# %%
df.JobCity.value_counts().nlargest(20).plot(kind='bar')
plt.show()

# %% [markdown]
# ### Observation
# * The most persons are living in Bangalore.

# %% [markdown]
# ## Date of birth

# %%
import datetime

# %%
# Pie plot,Univariate
dob = []
dob1 = []
for i in df.DOB:
    dob.append(i.strftime('%Y'))
    dob1.append(i.strftime('%Y %b %d'))

df['DOB'] = dob1
df['Birth_year'] = dob

# %%
plt.figure(figsize=(10,10))
df.Birth_year.value_counts().plot(kind='pie',table = True,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### Observations
# * The most of the employees birth in the 1991.
# * Yongest employee's Birth year is 1997.
# * Oldest employee's Birth year is 1977.

# %% [markdown]
# ## 10Percentage

# %%
df["10percentage"].value_counts()
# Out:
# 78.00    76
# 82.00    71
# 85.00    67
# 76.00    66
# 73.00    65
#          ..
# 75.85     1
# 54.40     1
# 53.06     1
# 75.75     1
# 89.25     1
# Name: 10percentage, Length: 851, dtype: int64

# %%
# barplot,Univariate
df['10percentage'].value_counts().nlargest(20).plot.bar()
plt.show()

# %% [markdown]
# ### Observations
# * The most of the persons got 78% in the given dataset.

# %% [markdown]
# ## 10board

# %%
# Pie plot,univariate
plt.figure(figsize=(10,10))
df['10board'].value_counts().nlargest(10).plot(kind='pie')
plt.show()

# %% [markdown]
# ### Observations :
#  * From the dataset, the 10th board column has 275 unique elements.
#  * Among all the 10th boards most are came from `CBSE`

# %% [markdown]
# ## 12graduation

# %%
# Countplot,Univariate
plt.figure(figsize=(10,6))
sns.countplot(x=df['12graduation'])
plt.show()

# %% [markdown]
# ### Observations :
#  * Most of the employees are 12Graduated in the year of 2009.

# %% [markdown]
# ## 12board

# %%
# Countplot,Univariate
df['12board'].value_counts().nlargest(20).plot.bar()
plt.show()

# %% [markdown]
# ### Observations :
# * Most of employees 12th graduation from CBSE, then State Board.
# * In this dataset some employees not provided their 12th board.

# %% [markdown]
# ## College Id

# %%
# Violin,univariate
sns.catplot(y='CollegeID',data=df,kind='violin')
plt.show()

# %% [markdown]
# ### Observations :
# * By looking we know that some of the College Id's are repeated.
# * College Id's are not unique beacuse employees are from different bords.

# %% [markdown]
# ## CollegeTier

# %%
# Countplot,univariate
sns.countplot(df['CollegeTier'])
plt.show()

# %% [markdown]
# ###  Observations :
# * By looking the plot most of the colleges are comes under Tier 2, Very few colleges i.e., 279 comes under Tier 1.

# %% [markdown]
# ## Degree

# %%
# Countplot,Univariate
sns.catplot(x='Degree',data=df,kind='count')
plt.show()

# %% [markdown]
# ###  Observations
# * From the plot we know that most of the employees are from `B.Tech/B.E`.

# %% [markdown]
# ## Speialization

# %%
# Barplot,univariate
df['Specialization'].value_counts().nlargest(20).plot.bar()
plt.show()

# %% [markdown]
# ### Observations
# * From the above plot most of persons have electronics and communication engineering.

# %% [markdown]
# ### Scatter plot
# * Scatter plots (also called scatter graphs) are similar to line graphs. A line graph uses a line on an X-Y axis to plot a continuous function, while a scatter plot uses dots to represent individual pieces of data. In statistics, these plots are useful to see if two variables are related to each other.

# %%
plt.scatter(x="ComputerProgramming",y="Salary",data=df)
plt.xlabel('ComputerProgramming')
plt.ylabel('Salary')
plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %% [markdown]
# ### Observations
# * The scatterplot above suggests that Computer Progamming and Salary are positively correlated.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   int64
#  2   DOJ                    3998 non-null   object
#  3   DOL                    3998 non-null   object
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   object
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
# regplot
sns.regplot(x='ComputerProgramming', y='Salary',data=df)

# %% [markdown]
# * To double-check the strength of this relationship, you might like to add a regression line, or the line that best fits the data. We do this by changing the command to sns.regplot.
# *

# %% [markdown]
# ### Pair Plots
# * Lets say we have n number of features in a data, Pair plot will create us a (n x n) figure where the diagonal plots will be histogram plot of the feature corresponding to that row and rest of the plots are the combination of feature from each row in y axis and feature from each column in x axis.

# %%
sns.pairplot(df,height=1.5)

# %%
plt.figure(figsize=(18,6))
ax = sns.barplot(x="ComputerProgramming", y="Salary",hue="Degree" ,data=df,ci=None,saturation=2)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observations
# * The above barplots shows the computer Programming salaries.
# * -1 means their salary not mentioned,most of persons they salaries not mentioned.

# %%
plt.figure(figsize=(18,6))
ax = sns.barplot(x="ElectricalEngg", y="Salary",hue="Degree" ,data=df,ci=None,saturation=2)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observations
# * The above barplots shows the ElectricalEngg salaries.
# * -1 means their salary not mentioned,some of persons they salaries not mentioned.

# %%
plt.figure(figsize=(18,6))
sns.barplot(y='Salary',x='English',data=df)
plt.title('Salary & English')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observations
# * The above barplot shows the English persons salary.
# * The heighest salary is near to 1600000 and most the persons have heighest salaries.

# %%
plt.figure(figsize=(18,6))
sns.catplot(y='Salary',x='Degree',kind='violin',data=df)
plt.title('Salary & Degree')
#plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### we created barplot  of  all students with thier engineering disciplines with thier salaries.

# %%
for i in ['ComputerProgramming',
       'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
       'ElectricalEngg', 'TelecomEngg', 'CivilEngg']:  
    plt.figure(figsize=(18,6))
    sns.barplot(y='Salary',x=i,data=df)
    plt.title('Salary & '+str(i))
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in ['conscientiousness',
       'agreeableness', 'extraversion', 'nueroticism', 'openess_to_experience',
       'Birth_year']:
    plt.figure(figsize=(18,6))
    sns.barplot(y='Salary',x=i,data=df)
    plt.title('Salary & '+i)
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# ## Multi variate analysis

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='Salary',x='GraduationYear',hue='Gender',data=df)
plt.title('Salary & GraduationYear')
plt.show()

# %% [markdown]
# ### Observations
# * We found the which graduation year have more salaries with gender.
# * The most of the female have more salary compare to male.

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='CollegeCityTier',x='CollegeTier',hue='Gender',data=df)
plt.title('CollegeCityTier,Gender & CollegeTier')
plt.show()

# %%
grp = df.groupby(by='Degree')

# %%
grp.aggregate('mean')

# %%
grp.MechanicalEngg.sum().plot.bar()

# %% [markdown]
# ## Histogram
# * Histograms represent the data distribution by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Salary'])
plt.ylabel('Frequency')

# %% [markdown]
# ## Box Plot
# * This is the type of plot that can be used to obtain more of the statistical details about the data. The straight lines at the maximum and minimum are also called as whiskers. Points outside of whiskers will be inferred as an outliers. The box plot gives us a representation of 25th, 50th ,75th quartiles.From box plot we can also see the Interquartile range(IQR) where maximum details of the data will be present. It also gives us a clear overview of outlier points in the data.
# ![image.png](attachment:image.png)

# %%
# Uni variate
sns.boxplot(y='Salary', data=df)

# %% [markdown]
# ### Observations
#
# * There are mor outliers in Salary datapoints.
# * The average Salary is the 30000

# %%
# Bi Variate
sns.boxplot(y='Salary',x="Gender" ,data=df)

# %% [markdown]
# ### Observations
# * There are some outliers in female candidates and More outliers  in Male candidates.
# * The avg Salary of Female is 30,000.
# * The avg Salary of Male candidates is 30,000

# %%
plt.figure(figsize=(10,6))
sns.boxplot(y='Salary',x="Gender" ,hue="Degree",data=df)

# %% [markdown]
# ### Observations
# * we found the female and male candidates outliers with thier degrees
# * In male candidates B.Tech/B.E. have more outliers compare to all other degrees.
# * No outliers in Msc(Tech)

# %%
plt.figure(figsize=(15,6))
plt.title('Salary')
sns.boxplot(y='Salary',x='ElectricalEngg',hue='Degree',data=df)
plt.xticks(rotation=60)
plt.show()
